# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys
import gc

cwd = os.getcwd()
base_dir = os.path.dirname(cwd)
data_dir = base_dir + "/data/navion_data/data"
ignore_file = None
src_dir = base_dir + "/src"

print("data dir: ", data_dir)
print("src dir: ", src_dir)


sys.path.insert(0, src_dir)

from data_analysis import load_data, convert_frames, plot_positions, plot_quiver_slice, plot_quiver_3d, correct_sensor_bias, load_raw_set_of_pkls

# %%
df = convert_frames(load_raw_set_of_pkls(data_dir))

# %%
plot_positions(df)
