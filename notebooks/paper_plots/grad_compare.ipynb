# %%
import os, sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

cwd = os.getcwd()
parent_dir = os.path.dirname(cwd)
base_dir = os.path.dirname(parent_dir)
src_dir = os.path.join(base_dir, "src")
octomag_package_dir = os.path.join(parent_dir, "testing", "evaluation_packages")
navion_package_dir = os.path.join(parent_dir, "testing", "evaluation_packages", "navion")
octomag_grads_dir = os.path.join(parent_dir, "gradients", "data")
navion_grads_dir = os.path.join(parent_dir, "gradients", "data_navion")
plot_dir = cwd + "/plots/"

sys.path.insert(0, src_dir)

from evaluate import ModelPhantom, EvaluationPackage, metrics # From main src dir 
from paper import latex_utils

# %%
test_package_name = "test_eval_pack.pkl"
training_package_name = "train_eval_pack.pkl"

# %%
test_package, training_package = None, None

try:
    print("Loading test set evaluation packages...")
    octomag_test_package = EvaluationPackage.load_from(octomag_package_dir + "/" + test_package_name)
    navion_test_package = EvaluationPackage.load_from(navion_package_dir + "/" + test_package_name)
    print("Successfully loaded test set evaluation packages.\n")
except Exception as e:
    print(f"Error loading test set evaluation package: {e}\n")

try:
    print("Loading training set evaluation packages...")
    octomag_training_package = EvaluationPackage.load_from(octomag_package_dir + "/" + training_package_name)
    navion_training_package = EvaluationPackage.load_from(navion_package_dir + "/" + training_package_name)
    print("Successfully loaded training set evaluation packages.\n")
except Exception as e:
    print(f"Error loading training set evaluation package: {e}\n")

# %%
###############################
####### Which metrics? ########
###############################

metrics_list = [
    metrics.grad_curl_div
]

##############################
####### Which models? ########
##############################

models = [
    ModelPhantom(name="ActuationNet", dataset_percentage=100, structure=(512, 512, 512)),
    ModelPhantom(name="ActuationNet", dataset_percentage=100, structure=(256, 256, 256)),
    ModelPhantom(name="ActuationNet", dataset_percentage=100, structure=(256, 256)),
    ModelPhantom(name="ActuationNet", dataset_percentage=50, structure=(512, 512, 512)),
    ModelPhantom(name="ActuationNet", dataset_percentage=20, structure=(512, 512, 512)),
    ModelPhantom(name="ActuationNet", dataset_percentage=5, structure=(512, 512, 512)),
    ModelPhantom(name="ActuationNet", dataset_percentage=1, structure=(512, 512, 512)),
    ModelPhantom(name="PotentialNet", dataset_percentage=100, structure=(512, 512, 512)),
    ModelPhantom(name="PotentialNet", dataset_percentage=100, structure=(256, 256, 256)),
    ModelPhantom(name="PotentialNet", dataset_percentage=100, structure=(256, 256)),
    ModelPhantom(name="PotentialNet", dataset_percentage=50, structure=(512, 512, 512)),
    ModelPhantom(name="PotentialNet", dataset_percentage=20, structure=(512, 512, 512)),
    ModelPhantom(name="PotentialNet", dataset_percentage=5, structure=(512, 512, 512)),
    ModelPhantom(name="PotentialNet", dataset_percentage=1, structure=(512, 512, 512)),
    ModelPhantom(name="DirectNet", dataset_percentage=100, structure=(512, 512, 512)),
    ModelPhantom(name="DirectNet", dataset_percentage=100, structure=(256, 256, 256)),
    ModelPhantom(name="DirectNet", dataset_percentage=100, structure=(256, 256)),
    ModelPhantom(name="DirectNet", dataset_percentage=50, structure=(512, 512, 512)),
    ModelPhantom(name="DirectNet", dataset_percentage=20, structure=(512, 512, 512)),
    ModelPhantom(name="DirectNet", dataset_percentage=5, structure=(512, 512, 512)),
    ModelPhantom(name="DirectNet", dataset_percentage=1, structure=(512, 512, 512)),
    ModelPhantom(name="DirectGBT", dataset_percentage=100, structure=(128,)),
    ModelPhantom(name="DirectGBT", dataset_percentage=100, structure=(64,)),
    ModelPhantom(name="DirectGBT", dataset_percentage=100, structure=(32,)),
    ModelPhantom(name="DirectGBT", dataset_percentage=50, structure=(128,)),
    ModelPhantom(name="DirectGBT", dataset_percentage=20, structure=(128,)),
    ModelPhantom(name="DirectGBT", dataset_percentage=5, structure=(128,)),
    ModelPhantom(name="DirectGBT", dataset_percentage=1, structure=(128,)),
    # ModelPhantom(name="MPEM", dataset_percentage=100, structure=(1,)),
    # ModelPhantom(name="MPEM", dataset_percentage=100, structure=(2,)),
    # ModelPhantom(name="MPEM", dataset_percentage=100, structure=(3,)),
    # ModelPhantom(name="MPEM", dataset_percentage=50, structure=(3,)),
    # ModelPhantom(name="MPEM", dataset_percentage=20, structure=(3,)),
    # ModelPhantom(name="MPEM", dataset_percentage=5, structure=(3,)),
    # ModelPhantom(name="MPEM", dataset_percentage=1, structure=(3,)),
]

full_models = [model for model in models if model.dataset_percentage == 100]
large_models = [model for model in models if model.structure == (512, 512, 512) or model.structure == (128,)]
large_full_models = [model for model in large_models if model.dataset_percentage == 100]

# Compute metrics
for metric in metrics_list:
    print(f"Computing {metric.__name__} for test set...")
    octomag_test_package.apply_gradient_metric(metric)
    navion_test_package.apply_gradient_metric(metric)
    print(f"Computing {metric.__name__} for training set...")
    octomag_training_package.apply_gradient_metric(metric)
    navion_training_package.apply_gradient_metric(metric)
    print()

# %%
# Load polyfit gradients
with open(octomag_grads_dir+"/poly_grads.pkl", "rb") as f:
    octomag_loaded_grads_dict = pickle.load(f)
with open(navion_grads_dir+"/poly_grads.pkl", "rb") as f:
    navion_loaded_grads_dict = pickle.load(f)

# Define which order and how many supporting points
order = 1
supporting_points = 3**3
label = "1st order fit"

# %%
def plot_div_curl_box_suite_dual_dataset(
    octomag_pkg,
    navion_pkg,
    models,
    *,
    div_key="div",
    curl_key="curl",

    # --- optional polynomial-fit references ---
    octomag_gradient_reference_dict=None,
    navion_gradient_reference_dict=None,
    polyfit_order=None,
    polyfit_nn_count=None,
    polyfit_label="Polynomial fit",

    # --- dataset styling ---
    dataset_names=("OctoMag", "Navion"),
    dataset_styles=None,
    # example default:
    # {
    #   "OctoMag": {"alpha": 0.95, "hatch": None,  "linewidth": 1.1},
    #   "Navion":  {"alpha": 0.45, "hatch": "//",  "linewidth": 1.1},
    # }

    verbose=True,

    # --- sizing ---
    figsize=(4.8, 5.25),

    # --- labels ---
    suptitle=r"Maxwell residuals",
    ylabel_div=r"$\nabla \cdot \field \;\;(\mathrm{mT}\,\mathrm{mm}^{-1})$",
    ylabel_curl=r"$\|\nabla\times \field\| \;\;(\mathrm{mT}\,\mathrm{mm}^{-1})$",
    title_div="Divergence",
    title_curl="Curl",

    # --- x tick labels ---
    rotate_xticks=28,
    xtick_ha="right",

    # --- box geometry ---
    showfliers=False,
    box_width=0.16,
    pair_gap=0.18,   # distance between OctoMag/Navion within same model
    linewidth=1.0,
    xpad=0.20,

    # --- layout ---
    hspace=0.35,
    top=0.84,
    bottom=0.28,
    left=0.18,
    right=0.98,

    # --- colors ---
    name_to_color=None,

    # --- legend ---
    legend_loc="upper left",
    legend_bbox_to_anchor=(0.02, 0.98),

    # --- latex rc ---
    latex_params=None,
    usetex=True,

    # --- output ---
    out="maxwell_dual_dataset.pdf",
    save=True,
    show=True,
):
    """
    Plot curl and divergence boxplots for OctoMag and Navion side by side
    for each model. Same model color is used for both datasets, with
    dataset-specific alpha / hatch styling.

    Returns
    -------
    fig, (ax_curl, ax_div), df, palette
    """

    def _metric_leaf_grad(pkg_, phantom_):
        name, dataset_percentage, structure = phantom_.keys()
        try:
            return pkg_.gradient_metrics[name][int(dataset_percentage)][structure]
        except Exception as e:
            raise KeyError(
                f"Missing gradient metrics for model '{phantom_.string(verbose=True)}'. "
                f"Did you run pkg.apply_gradient_metric(metrics.grad_curl_div) first?"
            ) from e

    def _base_name(ph):
        return ph.keys()[0]

    def _as_1d(a, key, lbl):
        a = np.asarray(a)
        if a.ndim == 0:
            return a.reshape(1)
        if a.ndim != 1:
            raise ValueError(f"{key} for '{lbl}' must be 1D, got shape {a.shape}")
        return a

    def _as_grad_array(g, lbl):
        g = np.asarray(g)
        if g.ndim == 3 and g.shape[1:] == (3, 3):
            return g
        if g.ndim == 2 and g.shape[1] == 9:
            return g.reshape(len(g), 3, 3)
        raise ValueError(
            f"Gradient array for '{lbl}' must have shape (N, 3, 3) or (N, 9), got {g.shape}"
        )

    def _div_curl_from_jacobian(J, lbl):
        J = _as_grad_array(J, lbl)

        dBx_dx = J[:, 0, 0]
        dBx_dy = J[:, 0, 1]
        dBx_dz = J[:, 0, 2]

        dBy_dx = J[:, 1, 0]
        dBy_dy = J[:, 1, 1]
        dBy_dz = J[:, 1, 2]

        dBz_dx = J[:, 2, 0]
        dBz_dy = J[:, 2, 1]
        dBz_dz = J[:, 2, 2]

        div = dBx_dx + dBy_dy + dBz_dz

        curl_x = dBz_dy - dBy_dz
        curl_y = dBx_dz - dBz_dx
        curl_z = dBy_dx - dBx_dy
        curl_mag = np.sqrt(curl_x**2 + curl_y**2 + curl_z**2)

        return div, curl_mag

    def _extract_polyfit_rows(gradient_reference_dict, dataset_label):
        if gradient_reference_dict is None:
            return []

        if polyfit_order is None or polyfit_nn_count is None:
            raise ValueError(
                "If a gradient_reference_dict is provided, polyfit_order and "
                "polyfit_nn_count must also be provided."
            )

        grads_tree = gradient_reference_dict["gradients"]
        poly_J = grads_tree[polyfit_order][polyfit_nn_count]
        poly_div_vals, poly_curl_vals = _div_curl_from_jacobian(poly_J, polyfit_label)

        rows = []
        rows += [
            {"dataset": dataset_label, "model_label": polyfit_label, "metric": div_key, "value": float(v)}
            for v in poly_div_vals
        ]
        rows += [
            {"dataset": dataset_label, "model_label": polyfit_label, "metric": curl_key, "value": float(v)}
            for v in poly_curl_vals
        ]

        if verbose:
            print(
                f"{dataset_label}: loaded polynomial-fit gradients "
                f"(order={polyfit_order}, nn_count={polyfit_nn_count}, n={len(poly_div_vals)})"
            )

        return rows

    # ----------------------------
    # labels
    # ----------------------------
    model_labels = [_base_name(m) for m in models]
    if len(set(model_labels)) != len(model_labels):
        raise ValueError(
            "Base-name labels are not unique. Pass only one phantom per base model."
        )

    polyfit_enabled = (
        octomag_gradient_reference_dict is not None or
        navion_gradient_reference_dict is not None
    )

    if polyfit_enabled and polyfit_label in model_labels:
        raise ValueError(f"polyfit_label='{polyfit_label}' collides with existing model label.")

    labels = model_labels + ([polyfit_label] if polyfit_enabled else [])

    # ----------------------------
    # build tidy dataframe
    # ----------------------------
    rows = []

    for pkg, ds_name in zip(
        [octomag_pkg, navion_pkg],
        dataset_names
    ):
        for ph, lbl in zip(models, model_labels):
            leaf = _metric_leaf_grad(pkg, ph)

            if div_key not in leaf or curl_key not in leaf:
                raise KeyError(
                    f"Gradient-metric leaf for '{lbl}' missing keys "
                    f"'{div_key}' and/or '{curl_key}'."
                )

            div_vals = _as_1d(leaf[div_key], div_key, lbl)
            curl_vals = _as_1d(leaf[curl_key], curl_key, lbl)

            rows += [
                {"dataset": ds_name, "model_label": lbl, "metric": div_key, "value": float(v)}
                for v in div_vals
            ]
            rows += [
                {"dataset": ds_name, "model_label": lbl, "metric": curl_key, "value": float(v)}
                for v in curl_vals
            ]

    rows += _extract_polyfit_rows(octomag_gradient_reference_dict, dataset_names[0])
    rows += _extract_polyfit_rows(navion_gradient_reference_dict, dataset_names[1])

    df = pd.DataFrame(rows)
    df["model_label"] = pd.Categorical(df["model_label"], categories=labels, ordered=True)
    df["dataset"] = pd.Categorical(df["dataset"], categories=list(dataset_names), ordered=True)

    # convert to mT/mm
    df["value"] = df["value"] * 1e-3

    # ----------------------------
    # palette
    # ----------------------------
    model_names = list(labels)
    sns_palette = sns.color_palette("deep", n_colors=len(model_names))

    if name_to_color is None:
        palette = {nm: sns_palette[i] for i, nm in enumerate(model_names)}
    else:
        palette = dict(name_to_color)
        for i, nm in enumerate(model_names):
            if nm not in palette:
                palette[nm] = sns_palette[i]

    if dataset_styles is None:
        dataset_styles = {
            dataset_names[0]: {"alpha": 0.95, "hatch": None, "linewidth": linewidth},
            dataset_names[1]: {"alpha": 0.45, "hatch": "//", "linewidth": linewidth},
        }

    latex_params = {} if latex_params is None else dict(latex_params)
    latex_params.setdefault("figsize", figsize)
    latex_params.setdefault("usetex", usetex)

    sns.set_style("whitegrid")

    with latex_utils.rc_context_latex(**latex_params):
        fig, axes = plt.subplots(
            2, 1,
            figsize=figsize,
            constrained_layout=False,
            sharex=True
        )
        ax_curl, ax_div = axes

        fig.subplots_adjust(
            hspace=hspace, top=top, bottom=bottom, left=left, right=right
        )

        if suptitle:
            fig.suptitle(suptitle)

        centers = np.arange(len(labels))
        offsets = np.array([-pair_gap / 2, pair_gap / 2])

        def _draw_panel(ax, metric_key, ylabel, title):
            for i_model, model_label in enumerate(labels):
                for i_ds, ds_name in enumerate(dataset_names):
                    sub = df[
                        (df["metric"] == metric_key) &
                        (df["model_label"] == model_label) &
                        (df["dataset"] == ds_name)
                    ]

                    vals = sub["value"].to_numpy()
                    if len(vals) == 0:
                        continue

                    pos = centers[i_model] + offsets[i_ds]
                    style = dataset_styles[ds_name]
                    color = palette[model_label]

                    bp = ax.boxplot(
                        [vals],
                        positions=[pos],
                        widths=box_width,
                        patch_artist=True,
                        showfliers=showfliers,
                        whis=1.5,
                        medianprops=dict(color="black", linewidth=1.0),
                        boxprops=dict(linewidth=style.get("linewidth", linewidth)),
                        whiskerprops=dict(linewidth=style.get("linewidth", linewidth)),
                        capprops=dict(linewidth=style.get("linewidth", linewidth)),
                    )

                    box = bp["boxes"][0]
                    box.set_facecolor(color)
                    box.set_edgecolor(color)
                    box.set_alpha(style.get("alpha", 1.0))
                    if style.get("hatch", None):
                        box.set_hatch(style["hatch"])

                    for whisk in bp["whiskers"]:
                        whisk.set_color(color)
                        whisk.set_alpha(style.get("alpha", 1.0))

                    for cap in bp["caps"]:
                        cap.set_color(color)
                        cap.set_alpha(style.get("alpha", 1.0))

                    for med in bp["medians"]:
                        med.set_color("black")
                        med.set_linewidth(1.0)

            ax.set_title(title)
            ax.set_ylabel(ylabel)
            ax.set_xlabel("")
            ax.grid(True, alpha=0.22, linewidth=0.6)
            ax.spines["top"].set_visible(False)
            ax.spines["right"].set_visible(False)
            ax.set_xlim(-0.5 - xpad, len(labels) - 0.5 + xpad)

        _draw_panel(ax_curl, curl_key, ylabel_curl, title_curl)
        _draw_panel(ax_div, div_key, ylabel_div, title_div)

        ax_div.set_xticks(centers)
        ax_div.set_xticklabels(labels, rotation=rotate_xticks, ha=xtick_ha)
        ax_curl.tick_params(axis="x", labelbottom=False)

        from matplotlib.patches import Patch
        legend_handles = []
        for ds_name in dataset_names:
            st = dataset_styles[ds_name]
            legend_handles.append(
                Patch(
                    facecolor="gray",
                    edgecolor="gray",
                    alpha=st.get("alpha", 1.0),
                    hatch=st.get("hatch", None),
                    label=ds_name
                )
            )
        ax_curl.legend(
            handles=legend_handles,
            loc=legend_loc,
            bbox_to_anchor=legend_bbox_to_anchor,
            frameon=False,
        )

        fig.align_ylabels([ax_curl, ax_div])

        if save and out:
            os.makedirs(os.path.dirname(out), exist_ok=True)
            fig.savefig(out, bbox_inches="tight")

        if show:
            plt.show()
        else:
            plt.close(fig)

    return fig, (ax_curl, ax_div), df, palette

# %%
palette_order = ["ActuationNet", "PotentialNet", "DirectNet", "DirectGBT", "MPEM", label]
sns_pal = sns.color_palette("deep", n_colors=len(palette_order))
name_to_color = {nm: sns_pal[i] for i, nm in enumerate(palette_order)}

fig_dual, axes_dual, df_dual, pal_dual = plot_div_curl_box_suite_dual_dataset(
    octomag_test_package,
    navion_test_package,
    models=large_full_models,
    octomag_gradient_reference_dict=None,#octomag_loaded_grads_dict,
    navion_gradient_reference_dict=None,#navion_loaded_grads_dict,
    polyfit_order=None,
    polyfit_nn_count=supporting_points,
    polyfit_label=label,
    name_to_color=name_to_color,
    dataset_styles={
        "OctoMag": {"alpha": 0.95, "hatch": None, "linewidth": 1.0},
        "Navion":  {"alpha": 0.45, "hatch": "//", "linewidth": 1.0},
    },
    latex_params=latex_utils.latex_prms_singlecol,
    usetex=True,
    suptitle="",
    out=plot_dir + "maxwell_octomag_navion_side_by_side.pdf",
    figsize=(3.2, 4.2),
    box_width=0.3,
    pair_gap=0.35,
    legend_loc="upper left",
    legend_bbox_to_anchor=(0.02, 0.9),
    save=True,
    show=True,
)
