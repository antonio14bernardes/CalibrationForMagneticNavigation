# %% [markdown]
# # Let's evaluate the measurement noise

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys
from tqdm.auto import tqdm
import numpy as np
from matplotlib.lines import Line2D
import seaborn as sns


cwd = os.getcwd()
parent_dir = os.path.dirname(cwd)
base_dir = os.path.dirname(parent_dir)
octomag_data_dir = base_dir + "/data/octomag_data/split_dataset/"
navion_data_dir = base_dir + "/data/navion_data/split_dataset/"
src_dir = base_dir + "/src"
plot_dir = cwd + "/plots/"

sys.path.insert(0, src_dir)

from calibration import MPEM, ActuationNet
from paper import latex_utils

# %% [markdown]
# ## Load data

# %%
octomag_df = pd.read_pickle(octomag_data_dir + "/test_data.pkl")
navion_df = pd.read_pickle(navion_data_dir + "/test_data.pkl")

# %% [markdown]
# ## Load model

# %%
octomag_model_path = base_dir + "/mpem/optimized_parameters/" + "optimized_dipole_5.yaml"
octomag_model = MPEM(octomag_model_path)

navion_model_path = base_dir + "/mpem/mpem_navion/optimized_parameters/" + "optimized_dipole_100.yaml"
navion_model = MPEM(navion_model_path)

# %% [markdown]
# ## Helpful funcs

# %%
def skew_sym(vector):
    """Create a skew-symmetric matrix from a 3D vector."""
    x, y, z = vector
    return np.array([[0, -z, y],
                     [z, 0, -x],
                     [-y, x, 0]])

def get_pos_jacobian_and_field(pos, currents, model):
    """Compute the Jacobian of the magnetic field w.r.t. position using autograd."""
    pos = np.array(pos, )
    currents = np.array(currents)

    field, jacobian_pos = model.get_field_and_grad9(pos, currents)

    return field, jacobian_pos

def get_trace_of_product(J):
    return np.trace(J @ J.T)

def build_avg_of_traces(positions, currents, model):
    pos_traces = []
    angle_traces = []

    for position, current in tqdm(zip(positions, currents), total=len(positions), desc="Building sensitivity Jacobians"):
        B_pred, J_pos = get_pos_jacobian_and_field(position, current, model)
        J_angle = skew_sym(B_pred)

        pos_traces.append(get_trace_of_product(J_pos))
        angle_traces.append(get_trace_of_product(J_angle))

    avg_pos_trace = np.mean(pos_traces)
    avg_angle_trace = np.mean(angle_traces)

    return avg_pos_trace, avg_angle_trace

def compute_required_angle_noise(RMSE_desired, pos_noises, avg_pos_trace, avg_angle_trace):
    
    pos_vars = np.array(pos_noises) ** 2

    angle_vars = (RMSE_desired ** 2 - avg_pos_trace * pos_vars) / avg_angle_trace

    return np.sqrt(angle_vars)

def retain_valid_pairs(pos_noises, angle_noises):
    valid_pos_noises = []
    valid_angle_noises = []

    for pos_noise, angle_noise in zip(pos_noises, angle_noises):
        if np.isfinite(angle_noise) and angle_noise > 0:
            valid_pos_noises.append(pos_noise)
            valid_angle_noises.append(angle_noise)

    return valid_pos_noises, valid_angle_noises

# %% [markdown]
# ## Define the positional noise range to consider and the resolution

# %%
pos_stds_mm_min, pos_stds_mm_max = 0.0, 2.0
resolution_mm = 0.01

pos_stds_mm = np.arange(pos_stds_mm_min, pos_stds_mm_max + resolution_mm, resolution_mm)

# %% [markdown]
# ## Compute for Octomag

# %%
octomag_positions = octomag_df[["x", "y", "z"]].to_numpy()
octomag_currents  = octomag_df[[c for c in octomag_df.columns if c.startswith("em_")]].to_numpy()

octomag_pos_avg_trace, octomag_angle_avg_trace = build_avg_of_traces(octomag_positions, octomag_currents, octomag_model)
octomag_required_angle_stds_deg = compute_required_angle_noise(0.5, pos_stds_mm/1000.0, octomag_pos_avg_trace, octomag_angle_avg_trace) * (180 / np.pi)

octomag_pos_stds_mm_valid, octomag_angle_stds_deg_valid = retain_valid_pairs(pos_stds_mm, octomag_required_angle_stds_deg)

# %% [markdown]
# ## Compute for Navion

# %%
navion_positions = navion_df[["x", "y", "z"]].to_numpy()
navion_currents  = navion_df[[c for c in navion_df.columns if c.startswith("em_")]].to_numpy()

navion_pos_avg_trace, navion_angle_avg_trace = build_avg_of_traces(navion_positions, navion_currents, navion_model)
navion_required_angle_stds_deg = compute_required_angle_noise(3, pos_stds_mm/1000.0, navion_pos_avg_trace, navion_angle_avg_trace) * (180 / np.pi)

navion_pos_stds_mm_valid, navion_angle_stds_deg_valid = retain_valid_pairs(pos_stds_mm, navion_required_angle_stds_deg)

# %% [markdown]
# # Plot

# %%
def plot_measurement_noise_iso_rmse(
    oct_angles_deg,
    oct_pos_mm,
    nav_angles_deg,
    nav_pos_mm,
    *,
    figsize=(3.2, 2.0),
    ds_palette=None,
    latex_params=None,
    usetex=True,
    out="measurement_noise_iso_rmse.pdf",
    save=True,
    show=True,
    legend_loc="upper left",
    legend_anchor=(0.02, 0.98),
    legend_frameon=False,
    legend_ncol=1,
):
    if ds_palette is None:
        ds_palette = {"OctoMag": "#4C72B0", "Navion": "#DD8452"}

    latex_params = {} if latex_params is None else dict(latex_params)
    latex_params.setdefault("usetex", usetex)

    sns.set_theme(style="whitegrid", context="paper")

    with latex_utils.rc_context_latex(**latex_params):
        fig = plt.figure(figsize=figsize, constrained_layout=False)
        ax = fig.add_subplot(111)

        ax.plot(
            oct_angles_deg,
            oct_pos_mm,
            color=ds_palette["OctoMag"],
            linewidth=2.0,
            label=r"OctoMag Iso-RMSE: 0.5 mT",
        )

        ax.plot(
            nav_angles_deg,
            nav_pos_mm,
            color=ds_palette["Navion"],
            linewidth=2.0,
            label=r"Navion Iso-RMSE: 3 mT",
        )

        ax.set_xlabel(r"Orientation $\sigma_{\theta}$ (deg)")
        ax.set_ylabel(r"Position $\sigma_{p}$ (mm)")
        ax.grid(True, alpha=0.3)

        ax.legend(
            loc=legend_loc,
            bbox_to_anchor=legend_anchor,
            frameon=legend_frameon,
            ncol=legend_ncol,
        )

        if save and out:
            os.makedirs(os.path.dirname(out), exist_ok=True)
            fig.savefig(out, bbox_inches="tight")

        if show:
            plt.show()
        else:
            plt.close(fig)

    return fig, ax

# %%
fig, ax = plot_measurement_noise_iso_rmse(
    octomag_angle_stds_deg_valid,
    octomag_pos_stds_mm_valid,
    navion_angle_stds_deg_valid,
    navion_pos_stds_mm_valid,
    figsize=(3.2, 1.5),
    ds_palette={"OctoMag": "#4C72B0", "Navion": "#DD8452"},
    latex_params=latex_utils.latex_prms_singlecol,
    usetex=True,
    out=plot_dir + "measurement_noise_iso_rmse_Octomag_and_Navion.pdf",
    save=True,
    show=True,
    legend_loc="upper left",
    legend_anchor=(0.0, -0.35),
)
